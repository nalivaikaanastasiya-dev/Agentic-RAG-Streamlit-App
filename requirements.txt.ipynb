# %% [markdown]
# <a href="https://colab.research.google.com/github/nalivaikaanastasiya-dev/Agentic-RAG-Streamlit-App/blob/main/requirements.txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
streamlit
langchain
langchain-community
langchain-groq
tavily-python
faiss-cpu
tiktoken
python-dotenv
sentence-transformers
