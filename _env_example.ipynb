# %% [markdown]
# <a href="https://colab.research.google.com/github/nalivaikaanastasiya-dev/Agentic-RAG-Streamlit-App/blob/main/_env_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# _env_example.ipynb
# Пример переменных окружения для проекта Agentic-RAG

# Для OpenAI GPT API
OPENAI_API_KEY = "your_openai_api_key_here"

# Для векторного хранилища Chroma
CHROMA_DB_PATH = "./chroma_db"

# Любые другие ключи (например Pinecone, Weaviate и т.д.)
# PINECONE_API_KEY = "your_pinecone_key_here"
# PINECONE_ENV = "your_pinecone_env_here"

print("Пример .env настроен. Не содержит реальных ключей.")
