# %% [markdown]
# <a href="https://colab.research.google.com/github/nalivaikaanastasiya-dev/Agentic-RAG-Streamlit-App/blob/main/_env_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# _env_example.ipynb
# Пример .env для Agentic RAG

# Groq LLM API
GROQ_API_KEY = "your_groq_api_key_here"

# Векторное хранилище
CHROMA_DB_PATH = "./chroma_db"

# Tavily Web Search
TAVILY_API_KEY = "your_tavily_api_key_here"

# LangSmith для логирования
LANGSMITH_API_KEY = "your_langsmith_api_key_here"

print("Пример .env готов. Замените ключи на свои реальные значения.")
