# %% [markdown]
# <a href="https://colab.research.google.com/github/nalivaikaanastasiya-dev/Agentic-RAG-Streamlit-App/blob/main/requirements_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
streamlit
python-dotenv

langchain
langchain-community
langchainhub
langgraph

langchain-groq
tavily-python

chromadb
faiss-cpu
tiktoken
bs4

langchain-google-genai
ipykernel
